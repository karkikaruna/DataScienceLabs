# %% [markdown]
# # LAB- **2**

# %% [markdown]
# # Utilize tools to create effective data visualizations (e.g., line charts, bar charts, heat maps, box plots) to derive key insights from the dataset

# %%
# !pip install pandas matplotlib seaborn

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/penguins_lter (1).csv")

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.shape
# Out:
# (344, 17)

# %% [markdown]
# # Scatterplot

# %% [markdown]
# A scatter plot is a plot or mathematical diagram using Cartesian coordinates to display values for typically two variables for a set of data. Here each value in the data set is represented by a dot. It is used for understanding the relationship between the 2 variables.

# %%
plt.figure(figsize=(12, 5))
plt.scatter(df['Culmen Depth (mm)'], df['Culmen Length (mm)'], color='red', marker='*')
plt.title("Scatterplot using Matplotlib")
plt.xlabel('Culmen Depth (mm)')
plt.ylabel('Culmen Length (mm)')
plt.grid()
plt.show()

# %%
df['Species'].unique()
# Out:
# array(['Adelie Penguin (Pygoscelis adeliae)',
#        'Chinstrap penguin (Pygoscelis antarctica)',
#        'Gentoo penguin (Pygoscelis papua)'], dtype=object)

# %%
df.tail()
# Out:
#     studyName  Sample Number                            Species  Region  \
# 339   PAL0910            120  Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121  Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122  Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123  Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124  Gentoo penguin (Pygoscelis papua)  Anvers
#
#      Island               Stage Individual ID Clutch Completion  Date Egg  \
# 339  Biscoe  Adult, 1 Egg Stage         N38A2                No   12/1/09
# 340  Biscoe  Adult, 1 Egg Stage         N39A1               Yes  11/22/09
# 341  Biscoe  Adult, 1 Egg Stage         N39A2               Yes  11/22/09
# 342  Biscoe  Adult, 1 Egg Stage         N43A1               Yes  11/22/09
# 343  Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      studyName  Sample Number  Species  Region  Island  Stage  Individual ID  \
# 0        False          False    False   False   False  False          False
# 1        False          False    False   False   False  False          False
# 2        False          False    False   False   False  False          False
# 3        False          False    False   False   False  False          False
# 4        False          False    False   False   False  False          False
# ..         ...            ...      ...     ...     ...    ...            ...
# 339      False          False    False   False   False  False          False
# 340      False          False    False   False   False  False          False
# 341      False          False    False   False   False  False          False
# 342      False          False    False   False   False  False          False
# 343      False          False    False   False   False  False          False
#
# ...

# %%
colors = {'Adelie Penguin (Pygoscelis adeliae)': 'red', 'Chinstrap penguin (Pygoscelis antarctica)': 'green', 'Gentoo penguin (Pygoscelis papua)': 'blue'}

markers = {'Adelie Penguin (Pygoscelis adeliae)': 'o', 'Chinstrap penguin (Pygoscelis antarctica)': 's', 'Gentoo penguin (Pygoscelis papua)': '^'}

plt.figure(figsize=(10, 6))

for species in df['Species'].unique():
    subset = df[df['Species'] == species]
    # print(subset)
    plt.scatter(subset['Culmen Depth (mm)'], subset['Culmen Length (mm)'],
                color=colors[species], label=species, edgecolor='Yellow', marker=markers[species])


plt.title('Culmen Depth vs Culmen Length (Matplotlib)')
plt.xlabel('Culmen Depth (mm)')
plt.ylabel('Culmen Length (mm)')
plt.legend(title='Species')
plt.grid()
plt.show()

# %% [markdown]
# The scatterplot visulizes the culmen Depth on the x-axis and culmen Length on the Y-axis.
# According to the above scatterplot follwing conclusions can be drawn.
#
#
# *   Adelie penguins have the smallest culmen lengths and moderate culmen depths.
#
# *  Chinstrap penguins have higher culmen depths and longer culmen lengths compared to Adelie penguins.
#
# *  Gentoo penguins have the longest culmen lengths but lower culmen depths.

# %%
adelie_count = (df["Species"] == "Adelie Penguin (Pygoscelis adeliae)").sum()
print("Number of Adelie Penguins:", adelie_count)
# Out:
# Number of Adelie Penguins: 152

# %%
chinstrap_count = (df["Species"] == "Chinstrap penguin (Pygoscelis antarctica)").sum()
print("Number of Chinstrap penguins:", chinstrap_count)
# Out:
# Number of Chinstrap penguins: 68

# %%
gentoo_count = (df["Species"] == "Gentoo penguin (Pygoscelis papua)").sum()
print("Number of gentoo penguins:", gentoo_count)
# Out:
# Number of gentoo penguins: 124

# %%
# Seaborn Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x=df['Culmen Depth (mm)'],
    y=df['Culmen Length (mm)'],
    hue=df['Species']
).set(title="Scatterplot using seaborn")


# Seaborn Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Culmen Depth (mm)', y='Culmen Length (mm)', hue='Species', style='Species', palette='deep')
plt.title('Culmen Depth vs Culmen Length (Seaborn)')
plt.show()

# %% [markdown]
# # **Bar Plot**
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.
#
# For the bar plot, We visualize the species on the X axis and counts on the Y axis.

# %%
#Bar Plot

#Matplotlib Bar Plot
# Count the occurrences of each species
species_counts = df['Species'].value_counts()
species_counts_df = species_counts.reset_index()
print(species_counts)
print(species_counts_df)

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(species_counts.index, species_counts.values, color='maroon')

# Adding labels and title
plt.title('Bar Plot of Penguin Species (Matplotlib)')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64
#                                      Species  count
# 0        Adelie Penguin (Pygoscelis adeliae)    152
# 1          Gentoo penguin (Pygoscelis papua)    124
# 2  Chinstrap penguin (Pygoscelis antarctica)     68

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=species_counts_df, x='Species', y='count', palette='cividis').set(title='Bar Plot of Penguin Species (Seaborn)')
# Out:
# <ipython-input-83-6cfdbf97f1de>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=species_counts_df, x='Species', y='count', palette='cividis').set(title='Bar Plot of Penguin Species (Seaborn)')
# [Text(0.5, 1.0, 'Bar Plot of Penguin Species (Seaborn)')]

# %%
# Plotting Bargraph for species and average culmen depth using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(df['Species'].unique(), df.groupby('Species')['Culmen Depth (mm)'].mean())
plt.title('Bar Plot of Penguin Species (Matplotlib)')
# Out:
# Text(0.5, 1.0, 'Bar Plot of Penguin Species (Matplotlib)')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Plotting Bargraph for species and average Culmen Length using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Species", y="Culmen Length (mm)", palette='viridis').set(title='Bar Plot of penguin Species (Seaborn)')
# Out:
# <ipython-input-82-b4cc15d0866f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Species", y="Culmen Length (mm)", palette='viridis').set(title='Bar Plot of penguin Species (Seaborn)')
# [Text(0.5, 1.0, 'Bar Plot of penguin Species (Seaborn)')]

# %% [markdown]
# # **Box Plot or Whisker Plot**
#
# Box plot was was first introduced in year 1969 by Mathematician John Tukey.Box plot give a statical summary of the features being plotted.Top line represent the max value,top edge of box is third Quartile, middle edge represents the median,bottom edge represents the first quartile value.The bottom most line respresent the minimum value of the feature.The height of the box is called as Interquartile range.The black dots on the plot represent the outlier values in the data.

# %%
#Matplotlib Boxplot
plt.figure(figsize=(10, 6))
df.boxplot(column='Culmen Depth (mm)', by='Species', grid=False)
plt.title('Box Plot of Culmen Depth (Matplotlib)')
plt.suptitle('')  # Used to suppress the default title to clean up the layout
plt.xlabel('Species')
plt.ylabel('Culmen Depth (mm)')
plt.show()

# %%
#Seaborn Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Species', y='Culmen Length (mm)', palette='cividis')
plt.title('Box Plot of Culmen Length (Seaborn)')
plt.xlabel('Species')
plt.ylabel('Culmen Length (mm)')
plt.show()
# Out:
# <ipython-input-87-3ae54b7735b2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Species', y='Culmen Length (mm)', palette='cividis')

# %% [markdown]
# # **Heat Map**
#
# A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours. The Seaborn package allows the creation of annotated heatmaps which can be tweaked using Matplotlib tools as per the creator's requirement.
#
# To create a heatmap of the Iris dataset, we typically focus on visualizing the correlation matrix, which shows the relationships between numerical features. A heatmap is a great way to visualize these correlations.
#
# Computes the Pearson correlation matrix, showing the pairwise correlation coefficients between numerical features. Values range from:
#
# +1: Perfect positive correlation.
#
# 0: No correlation.
#
# -1: Perfect negative correlation.

# %%
#First, compute the correlation matrix
correlation_matrix = df.select_dtypes(include=['number']).corr() # Select only numerical columns

plt.figure(figsize=(10, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation Coefficient')
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.title('Correlation Heatmap (Matplotlib)')
plt.clim(-1, 1)  # Set the color limit to match correlation coefficients
plt.show()

# %%
#First, compute the correlation matrix
correlation_matrix = df.select_dtypes(include=['number']).corr() # Select only numerical columns

#Seaborn Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', fmt='.2f', square=True)
plt.title('Correlation Heatmap (Seaborn)')
plt.show()

# %% [markdown]
# Note: Pallette can be magma, cividis, viridis, inferno, crest, coolwarm, 'dark', 'deep', 'muted', 'pastel', 'bright', 'colorblind'. Also, Pallette without hue will throw warnings.

# %% [markdown]
# # **Violin Plot**
#
# Violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual data points, the violin plot features a kernel density estimation of the underlying distribution.

# %%
#Matplotlib Violin Plot
# Prepare data for violin plot
species = df['Species'].unique()
data = [df[df['Species'] == s]['Culmen Length (mm)'] for s in species]

# Creating the violin plot
plt.figure(figsize=(10, 6))
plt.violinplot(data, showmeans=True, showmedians=True)

# Customizing the plot
plt.title('Violin Plot of Culmen Length (Matplotlib)')
plt.xlabel('Species')
plt.ylabel('Culmen Length (mm)')
plt.xticks(ticks=[1, 2, 3], labels=species)  # Set x-tick labels
plt.grid(axis='y')
plt.show()


#Seaborn Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Species', y='Culmen Depth (mm)', palette='inferno')
plt.title('Violin Plot of Culmen Depth (mm) (Seaborn)')
plt.xlabel('Species')
plt.ylabel('Culmen Depth (mm)')
plt.grid(axis='y')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# <ipython-input-94-93ceb668a4b5>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Species', y='Culmen Depth (mm)', palette='inferno')

# %% [markdown]
# # **Histogram**
#
# Histograms are used to represent the frequency distribution of continuous variables. The width of the histogram represents interval and the length represents frequency. To create a histogram you need to create bins of the interval which are not overlapping. Histogram allows the inspection of data for its underlying distribution, outliers, skewness.

# %%
#Matplotlib Histogram
plt.figure(figsize=(10, 6))

plt.hist(df['Culmen Length (mm)'], bins=10, label=species)

plt.title('Histogram of Culmen Length (Matplotlib)')
plt.xlabel('Sepal Culmen Length (mm)')
plt.ylabel('Frequency')
plt.show()

#Seaborn Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Culmen Length (mm)', bins=10, kde=True, alpha=0.5)

plt.title('Histogram of Culmen Length  (Seaborn)')
plt.xlabel('Culmen Length')
plt.ylabel('Frequency')
plt.show()

# %%
#Histogram Plots of Culmen Length

#Matplotlib Histogram
plt.figure(figsize=(10, 6))
for species in df['Species'].unique():
    subset = df[df['Species'] == species]
    plt.hist(subset['Culmen Length (mm)'], bins=10, alpha=0.5, label=species)

plt.title('Histogram of Culmen Length (Matplotlib)')
plt.xlabel('Culmen Length (mm)')
plt.ylabel('Frequency')
plt.legend(title='Species')
plt.show()


#Seaborn Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Culmen Length (mm)', hue='Species', bins=10, kde=True, alpha=0.5)

plt.title('Histogram of Culmen Length (Seaborn)')
plt.xlabel('Culmen Length (mm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Line Plots/Charts**
#
# Line plots is a graph that is used for the representation of continuous data points on a number line. Line plots are created by first plotting data points on the Cartesian plane then joining those points with a number line. Line plots can help display data points for both single variable analysis as well as multiple variable analysis.

# %%
plt.figure(figsize=(10, 6))

# Plot a line chart for each species
for species in df['Species'].unique():
    species_data = df[df['Species'] == species]
    print(species_data)
    plt.plot(species_data.index, species_data['Culmen Length (mm)'], label=species)

# Add titles and labels
plt.title('Line Chart of Culmen Length by Species')
plt.xlabel('Sample Index')
plt.ylabel('Culmen Length(mm)')

# Add a legend
plt.legend(title='Species')

# Show the plot
plt.show()
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 147   PAL0910            148  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 148   PAL0910            149  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 149   PAL0910            150  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 150   PAL0910            151  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 151   PAL0910            152  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create a line plot for each species
sns.lineplot(data=df, x=df.index, y='Culmen Length (mm)', hue='Species')

# Add titles and labels
plt.title('Line Chart of Culmen Length by Species')
plt.xlabel('Sample Index')
plt.ylabel('SCulmen Length (mm)')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x=df.index, y='Culmen Depth (mm)', marker='o')

# Set the title and labels
plt.title('Culmen Depth (mm)')
plt.xlabel('Index')
plt.ylabel('Culmen Depth (mm)')

# Display the plot
plt.show()
